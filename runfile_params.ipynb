# %%
import sys
from ipynb.fs.full.fix_coordinates import fix_X_coords, fix_Y_coords
import pandas as pd

# %%
xls = pd.ExcelFile('RAFA_2022_RUBROS_AGRICOLAS.xlsx')
MA = pd.read_excel(xls, 'MANDIOCA')
YM = pd.read_excel(xls, 'YERBA MATE')
PT = pd.read_excel(xls, 'POROTO')
SJ = pd.read_excel(xls, 'SOJA')
MZ = pd.read_excel(xls, 'MAIZ') 
CDA = pd.read_excel(xls, 'CAÑA DE AZUCAR') 
AR = pd.read_excel(xls, 'ARROZ')

# %%
fix_X_coords(AR)
# Out:
#     CIC. TECN.       NOMBRE Y APELLIDO TECNICO  CIC. PROD.  \
# 0      2056276   ADA ZULLY CONCEPCION ESPINOLA     2538038
# 1      3867307  IDALIA MARIA ORTELLADO CABRERA     5336423
# 2      4374049  FRANCISCO FERMIN ROMERO BENITE     1621407
# 3      1162305   NORMA NUÑEZ DA SILVEIRA VDA D     2281258
# 4      4581539       JUAN MANUEL AREVALOS VEGA     7583351
# 5      4581539       JUAN MANUEL AREVALOS VEGA     1743497
# 6      4581539       JUAN MANUEL AREVALOS VEGA     5206955
# 7      4494304    OTILIA MABEL GALEANO SERVIAN     1937748
# 8       882481      FELICIA TILLERIA DE NYMANN     7421902
# 9       882481      FELICIA TILLERIA DE NYMANN     1760124
# 10      838924  ANDRES GUTIERREZ DE LOS SANTOS     1461584
# 11      838924  ANDRES GUTIERREZ DE LOS SANTOS      326549
# 12      838924  ANDRES GUTIERREZ DE LOS SANTOS     5442751
# 13     1317773     RICARDO PAREDES INSAURRALDE     1579967
# 14     1317773     RICARDO PAREDES INSAURRALDE     2464820
# ...

# %%
fix_Y_coords(AR)
# Out:
#     CIC. TECN.       NOMBRE Y APELLIDO TECNICO  CIC. PROD.  \
# 0      2056276   ADA ZULLY CONCEPCION ESPINOLA     2538038
# 1      3867307  IDALIA MARIA ORTELLADO CABRERA     5336423
# 2      4374049  FRANCISCO FERMIN ROMERO BENITE     1621407
# 3      1162305   NORMA NUÑEZ DA SILVEIRA VDA D     2281258
# 4      4581539       JUAN MANUEL AREVALOS VEGA     7583351
# 5      4581539       JUAN MANUEL AREVALOS VEGA     1743497
# 6      4581539       JUAN MANUEL AREVALOS VEGA     5206955
# 7      4494304    OTILIA MABEL GALEANO SERVIAN     1937748
# 8       882481      FELICIA TILLERIA DE NYMANN     7421902
# 9       882481      FELICIA TILLERIA DE NYMANN     1760124
# 10      838924  ANDRES GUTIERREZ DE LOS SANTOS     1461584
# 11      838924  ANDRES GUTIERREZ DE LOS SANTOS      326549
# 12      838924  ANDRES GUTIERREZ DE LOS SANTOS     5442751
# 13     1317773     RICARDO PAREDES INSAURRALDE     1579967
# 14     1317773     RICARDO PAREDES INSAURRALDE     2464820
# ...

# %%
YM.to_csv('YERBA_MATE.csv')
