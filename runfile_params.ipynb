# %%
import sys
from ipynb.fs.full.fix_coordinates import fix_coords
import pandas as pd

# %%
xls = pd.ExcelFile('RAFA_2022_RUBROS_AGRICOLAS.xlsx')
MA = pd.read_excel(xls, 'MANDIOCA')
YM = pd.read_excel(xls, 'YERBA MATE')
PT = pd.read_excel(xls, 'POROTO')
SJ = pd.read_excel(xls, 'SOJA')
MZ = pd.read_excel(xls, 'MAIZ') 
CDA = pd.read_excel(xls, 'CAÑA DE AZUCAR') 
AR = pd.read_excel(xls, 'ARROZ')

# %%
fix_coords(SJ)
# Out:
#       CIC. TECN.       NOMBRE Y APELLIDO TECNICO  CIC. PROD.  \
# 0        4865154   EDGAR DIOSNEL GOMEZ FLORENTIN     7021785
# 1        3205520        MILCIADES VILLA VILLALBA     2163802
# 2        3205520        MILCIADES VILLA VILLALBA     5787002
# 3        3205520        MILCIADES VILLA VILLALBA     2528055
# 4        3205520        MILCIADES VILLA VILLALBA     3859989
# ...          ...                             ...         ...
# 1044     4689960       BLAS ALCIDES RIVAS OVELAR     1860378
# 1045     4689960       BLAS ALCIDES RIVAS OVELAR     5122948
# 1046     4549249  FREDY GABRIEL BALBUENA MIRANDA     1926366
# 1047     4054361              IRENEO GOMEZ AYALA     2079089
# 1048     4054361              IRENEO GOMEZ AYALA     2201088
#
#              NOMBRE Y APELLIDO TECNICO.1 CULTIVO DEPARTAMENTO         CDA  \
# 0       DIANA MERCEDES FERNANDEZ BARRETO    SOJA   CONCEPCION  CONCEPCION
# 1                 ABRAHAN IBARRA CUBILLA    SOJA   CONCEPCION  CONCEPCION
# 2     ANDREA DE LA PAZ INSFRAN GUTIERREZ    SOJA   CONCEPCION  CONCEPCION
# 3             ANSELMA CARDENAS DE ALONSO    SOJA   CONCEPCION  CONCEPCION
# 4                BALBINA AGÜERO DE SILVA    SOJA   CONCEPCION  CONCEPCION
# ...                                  ...     ...          ...         ...
# 1044            LUCIANO MARTINEZ CARDOZO    SOJA    CANINDEYU   CANINDEYÚ
# 1045      NINFA RAQUEL GABILAN FLORENTIN    SOJA    CANINDEYU   CANINDEYÚ
# 1046               EMILIO BENITEZ VILLAR    SOJA    CANINDEYU   CANINDEYÚ
# 1047             REINALDO CAIRE RETAMOSO    SOJA    CANINDEYU   CANINDEYÚ
# 1048              TEODORO AYALA VILLALBA    SOJA    CANINDEYU   CANINDEYÚ
#
#           ALAT  DISTRITO     COORD. X     COORD. Y        X_coord  \
# 0       AZOTEY    AZOTEY    234004138    566271046    -23.4004138
# 1       AZOTEY    AZOTEY  23239890337  56361929424  -23.239890337
# 2       AZOTEY    AZOTEY   2323552572   5637921332   -23.23552572
# 3       AZOTEY    AZOTEY   2323667810   5674564240   -23.23667810
# 4       AZOTEY    AZOTEY   2324083303   5639243057   -23.24083303
# ...        ...       ...          ...          ...            ...
# 1044  MARACANÁ  MARACANA  -24.1150526   -56.068381    -24.1150526
# 1045  MARACANÁ  MARACANA   -24,073395    -56,05782     -24.073395
# 1046  MARACANÁ  MARACANA  -24.1684019  -56.0124552    -24.1684019
# 1047  MARACANÁ  MARACANA   -24.170810   -56.060355     -24.170810
# 1048  MARACANÁ  MARACANA   -24.188000   -56.098303     -24.188000
#
#             Y_coord
# 0       -56.6271046
# 1     -56.361929424
# 2      -56.37921332
# 3      -56.74564240
# 4      -56.39243057
# ...             ...
# 1044     -56.068381
# 1045      -56.05782
# 1046    -56.0124552
# 1047     -56.060355
# 1048     -56.098303
#
# [1049 rows x 13 columns]

# %%
SJ.to_csv('SOJA.csv')
